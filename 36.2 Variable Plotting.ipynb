# %%
library(ggplot2)
library(ggplot2movies)
df <- movies

# %%
qplot(x=year, y=rating, data = df, geom = "density2d")
# Out:
# plot without title

# %%
pl <- ggplot(movies,aes(x = year,y=rating))
pl + geom_bin2d()
# Out:
# plot without title

# %%
pl <- ggplot(movies,aes(x = year,y=rating))
pl + geom_bin2d() + scale_fill_gradient(high='red',low= 'green')
# Out:
# plot without title

# %%
pl <- ggplot(movies,aes(x = year,y=rating))
pl + geom_bin2d(binwidth = c(3,1)) + scale_fill_gradient(high='red',low= 'green')
# Out:
# plot without title

# %%
pl <- ggplot(movies,aes(x = year,y=rating))
pl + geom_hex() + scale_fill_gradient(high='red',low= 'green')
# Out:
# Warning message:
# “Computation failed in `stat_binhex()`:
# Package `hexbin` required for `stat_binhex`.
# Please install and try again.”
# plot without title

# %%
install.packages('hexbin')
# Out:
# The downloaded binary packages are in
# 	/var/folders/py/lhhb009s773f7xlgffm6ysjw0000gn/T//RtmpHXSHA2/downloaded_packages

# %%
pl <- ggplot(movies,aes(x = year,y=rating))
pl + geom_hex() + scale_fill_gradient(high='red',low= 'green')
# Out:
# plot without title

# %%
pl <- ggplot(movies,aes(x = year,y=rating))
pl + geom_density2d() + scale_fill_gradient(low = "yellow", high = "red")
# Out:
# plot without title

# %%
ggplot(dataset2, aes(x, y)) + 
    stat_density2d(aes(alpha=..level.., fill=..level..), size=2, 
        bins=10, geom="polygon") + 
    scale_fill_gradient(low = "yellow", high = "red") +
    scale_alpha(range = c(0.00, 0.5), guide = FALSE) +
    geom_density2d(colour="black", bins=10) +
    geom_point(data = dataset) +
    guides(alpha=FALSE) + xlim(c(10, 160)) + ylim(c(120, 280))
