# %%
install.packages('ggplot2')
# Out:
# also installing the dependencies ‘colorspace’, ‘RColorBrewer’, ‘dichromat’, ‘munsell’, ‘labeling’, ‘gtable’, ‘plyr’, ‘reshape2’, ‘scales’
# The downloaded binary packages are in
# 	/var/folders/py/lhhb009s773f7xlgffm6ysjw0000gn/T//RtmpFCnutV/downloaded_packages

# %%
library(ggplot2)

# %%
pl <- ggplot(data = mtcars , aes(x=mpg, y= hp))

# %%
pl + geom_point()
# Out:
# plot without title

# %%
pl + geom_point() + facet_grid(cyl ~.)
# Out:
# plot without title

# %%
pl + geom_point() + facet_grid(cyl ~.) + stat_smooth()
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
pl + geom_point() + facet_grid(cyl ~.) + stat_smooth() + coord_cartesian(xlim = c(15,25))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
pl + geom_point() + facet_grid(cyl ~.) + stat_smooth() + coord_cartesian(xlim = c(15,25)) + theme_bw()
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
library(ggplot2)
library(ggthemes)
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
ggplot(mpg,aes(hwy)) + geom_bar(fill = 'red',binwidth = 1.5, alpha =0.5)
# Out:
# Warning message:
# “`geom_bar()` no longer has a `binwidth` parameter. Please use `geom_histogram()` instead.”
# plot without title

# %%
ggplot(mpg,aes(x= hwy)) + geom_histogram(bins =20,fill = 'red', alpha =0,5)
# Out:
# Error: Mapping must be created by `aes()` or `aes_()`
# Traceback:
#
# 1. geom_histogram(bins = 20, fill = "red", alpha = 0, 5)
# 2. layer(data = data, mapping = mapping, stat = stat, geom = GeomBar,
#  .     position = position, show.legend = show.legend, inherit.aes = inherit.aes,
#  .     params = list(binwidth = binwidth, bins = bins, na.rm = na.rm,
#  .         pad = FALSE, ...))
# 3. stop("Mapping must be created by `aes()` or `aes_()`", call. = FALSE)

# %%
ggplot(mpg,aes(manufacturer)) + geom_bar(aes(fill = factor(cyl)))
# Out:
# plot without title

# %%
head(txhousing)
# Out:
#   city    year month sales volume   median listings inventory date
# 1 Abilene 2000 1      72    5380000 71400  701      6.3       2000.000
# 2 Abilene 2000 2      98    6505000 58700  746      6.6       2000.083
# 3 Abilene 2000 3     130    9285000 58100  784      6.8       2000.167
# 4 Abilene 2000 4      98    9730000 68600  785      6.9       2000.250
# 5 Abilene 2000 5     141   10590000 67300  794      6.8       2000.333
# 6 Abilene 2000 6     156   13910000 66900  780      6.6       2000.417

# %%
ggplot(txhousing, aes(x = sales, y = volume)) + geom_point(color = 'blue', alpha =0.5) + stat_smooth(color = 'red')
# Out:
# `geom_smooth()` using method = 'gam'
# Warning message:
# “Removed 568 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 568 rows containing missing values (geom_point).”
# plot without title
