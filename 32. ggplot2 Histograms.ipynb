# %%
install.packages('ggplot2movies')
# Out:
# The downloaded binary packages are in
# 	/var/folders/py/lhhb009s773f7xlgffm6ysjw0000gn/T//RtmpkLTbi6/downloaded_packages

# %%
library(ggplot2)

# %%
library(ggplot2movies)

# %%
colnames(movies)
# Out:
#  [1] "title"       "year"        "length"      "budget"      "rating"
#  [6] "votes"       "r1"          "r2"          "r3"          "r4"
# [11] "r5"          "r6"          "r7"          "r8"          "r9"
# [16] "r10"         "mpaa"        "Action"      "Animation"   "Comedy"
# [21] "Drama"       "Documentary" "Romance"     "Short"

# %%
head(movies)
# Out:
#   title                    year length budget rating votes r1   r2   r3  r4   ⋯
# 1 $                        1971 121    NA     6.4    348    4.5  4.5 4.5  4.5 ⋯
# 2 $1000 a Touchdown        1939  71    NA     6.0     20    0.0 14.5 4.5 24.5 ⋯
# 3 $21 a Day Once a Month   1941   7    NA     8.2      5    0.0  0.0 0.0  0.0 ⋯
# 4 $40,000                  1996  70    NA     8.2      6   14.5  0.0 0.0  0.0 ⋯
# 5 $50,000 Climax Show, The 1975  71    NA     3.4     17   24.5  4.5 0.0 14.5 ⋯
# 6 $pent                    2000  91    NA     4.3     45    4.5  4.5 4.5 14.5 ⋯
#   r9   r10  mpaa Action Animation Comedy Drama Documentary Romance Short
# 1  4.5  4.5      0      0         1      1     0           0       0
# 2  4.5 14.5      0      0         1      0     0           0       0
# 3 24.5 24.5      0      1         0      0     0           0       1
# 4 34.5 45.5      0      0         1      0     0           0       0
# ...

# %%
p1 <- ggplot(movies, aes(x =rating))

# %%
p1 + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
p1 + geom_histogram(binwidth = 0.1, color = 'red')
# Out:
# plot without title

# %%
p1 + geom_histogram(binwidth = 0.1, color = 'red', fill = 'pink')
# Out:
# plot without title

# %%
p1 + geom_histogram(binwidth = 0.1, color = 'red', fill = 'blue' , alpha = 0.5)   # alpha for the color filling percentage.
# Out:
# plot without title

# %%
p2 <- p1 + geom_histogram(binwidth = 0.1, color = 'red', fill = 'blue' , alpha = 1)

# %%
p3 <- p2 + xlab('Movie Rating') + ylab('My rating')

# %%
print(p3)
# Out:
# plot without title

# %%
print(p3 + ggtitle("MY TITLE"))
# Out:
# plot without title

# %%
p1 + geom_histogram(binwidth =  0.1 , aes(fill = ..count..)) # Color changes
# Out:
# plot without title

# %%
pC <- p1 + geom_histogram(binwidth =  0.1 , aes(fill = ..count..)) 
pC + scale_fill_gradient('Count',low='blue',high='red')
# Out:
# plot without title

# %%
p1 + geom_histogram(binwidth=0.1,color='blue',fill='pink',linetype='dotted')
# Out:
# plot without title

# %%
p1 + geom_histogram(aes(y=..density..)) + geom_density(color='red')
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
